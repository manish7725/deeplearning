# %% [markdown]
# <a href="https://colab.research.google.com/github/manish7725/deeplearning/blob/main/Lecture%20NN%20-%20{{URL-encoded%20title}}/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lecture NN — {{Title}} · Code Laboratory
#
# ↩ **Theory:** [`blog.md`](<blog.md>) — read it first; this notebook does not repeat it.
#
# **You will build:** {{one line}}
#
# Run the cells in order. Each lab asks you to predict the result before you run it.

# %%
# Setup — runs on a fresh CPU runtime, no local files needed.
import numpy as np

np.random.seed(0)
print("numpy", np.__version__)

# %% [markdown]
# ## 🧪 Lab 1 — Reproduce the smallest example
# ↩ **Theory:** [`blog.md` §2](<blog.md>)
#
# The numbers below are the same ones used in the blog — do not change them.
#
# **Predict first:** {{what should this print?}}

# %%
# The blog's §2 example, exactly.
x = np.array([])
y = np.array([])

# assert <the blog's stated result>

# %% [markdown]
# ## 🧪 Lab 2 — NumPy implementation
# ↩ **Theory:** [`blog.md` §4](<blog.md>)
#
# $$
# {{the equation being implemented}}
# $$
#
# **Predict first:** {{what value should this converge to / return?}}

# %%
# Implement §4 with NumPy only — no framework shortcuts for the step being taught.

# Every numeric claim the blog makes gets asserted here:
# assert abs(result - expected) < 1e-6

# %% [markdown]
# ## 🧪 Lab 3 — Tensor / PyTorch form
# ↩ **Theory:** [`blog.md` §5](<blog.md>)
#
# Same mathematics, now on whole arrays. Watch the shapes.
#
# **Predict first:** {{what shape comes out?}}

# %%
import torch

# Same numbers as Lab 2, expressed as tensors.

# The two implementations must agree:
# assert np.allclose(numpy_result, torch_result.numpy(), atol=1e-5)

# %% [markdown]
# ## 🧪 Lab 4 — Visualization
# ↩ **Theory:** [`blog.md` §6](<blog.md>)
#
# **Predict first:** sketch the shape of this plot before running. Where does it rise,
# flatten or cross zero?

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(7, 4))
# Plot the chapter's own quantity — not a generic example.
ax.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🧪 Lab 5 — Change exactly one variable
# ↩ **Theory:** [`blog.md` §7](<blog.md>)
#
# One variable moves. Everything else — data, seed, initialization, steps — stays fixed.
#
# **Predict first:** {{which direction does the result move, and why?}}

# %%
# Changed variable: {{name}}. Held fixed: data, seed, initialization, steps.

for value in []:
    pass  # run and print the outcome for each value

# %% [markdown]
# ## 🧪 Lab 6 — Break it on purpose
# ↩ **Theory:** [`blog.md` §8](<blog.md>)
#
# Remove the assumption the chapter relies on and watch what the mathematics does.
#
# **Predict first:** {{what failure should appear — divergence, wrong shape, silent bias?}}

# %%
# Deliberately violate the assumption from §8.

# changed assumption -> {{…}}
# symptom            -> {{…}}
# mathematical reason -> {{…}}
# fix                 -> {{…}}

# %% [markdown]
# ## 🧪 Lab 7 — Exercises
# ↩ **Theory:** [`blog.md` §10](<blog.md>)
#
# Solve the blog's exercises in code. Write the expected answer as an `assert` first,
# then make it pass.

# %%
# Exercise 1

# Exercise 2

# Exercise 3

# %% [markdown]
# ## 🧪 Lab 8 — Mini-project
# ↩ **Theory:** [`blog.md` §11](<blog.md>)
#
# **Hypothesis:** {{what you expect}}
# **Measured:** {{the metric}}
# **A negative result looks like:** {{state it before running}}

# %%
# Build it. Finish with a written conclusion in the cell below the output.

# %% [markdown]
# ## ✅ Mastery check
#
# - [ ] I reproduced the blog's numbers by hand before running Lab 1.
# - [ ] I can map every equation in `blog.md` to a line of code above.
# - [ ] NumPy and tensor versions agree, and the asserts pass.
# - [ ] I predicted each plot and experiment before running it.
# - [ ] I changed exactly one variable in Lab 5.
# - [ ] I can explain the failure in Lab 6 mathematically, not just describe it.
#
# ➡️ **Next:** [`blog.md` §14](<blog.md>)
