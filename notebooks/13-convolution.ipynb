# %% [markdown]
# # Blog 13 — How a Neural Network Learns to See: Convolution

# %%
import numpy as np
image=np.arange(25).reshape(5,5)
kernel=np.array([[1,0,-1],[1,0,-1],[1,0,-1]])
out=np.array([[np.sum(image[i:i+3,j:j+3]*kernel) for j in range(3)] for i in range(3)])
print(out)
