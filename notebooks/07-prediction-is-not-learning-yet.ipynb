# %% [markdown]
# # Blog 07 — Prediction Is Not the Same as Learning

# %%
import numpy as np
x=np.array([1.,2.,3.]); y=np.array([3.,5.,7.])
for w,b in [(0,0),(2,1)]:
    p=w*x+b; print(w,b,'loss=',np.mean((p-y)**2))
