# %% [markdown]
# # Blog 14 — When Order Matters

# %%
import torch
rnn=torch.nn.RNN(input_size=1,hidden_size=4,batch_first=True)
x=torch.tensor([[[1.],[2.],[3.],[4.]]])
out,h=rnn(x); print(out.shape,h.shape)
