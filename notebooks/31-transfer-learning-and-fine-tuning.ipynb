# %% [markdown]
# # Blog 31 — Transfer Learning and Fine-Tuning

# %%
import torch
base=torch.nn.Linear(10,8); head=torch.nn.Linear(8,2)
for p in base.parameters(): p.requires_grad=False
x=torch.randn(4,10); print(head(base(x)).shape)
print('trainable head parameters:',sum(p.numel() for p in head.parameters()))
