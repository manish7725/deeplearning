# %% [markdown]
# # Blog 33 — Inference Methods

# %%
import torch
logits=torch.tensor([2.,1.,3.,.5]); probs=torch.softmax(logits,0)
print('greedy token:',torch.argmax(probs).item()); print('probabilities:',probs)
