# %% [markdown]
# # Blog 12 — How Do We Know If Our Model Really Learned?

# %%
import numpy as np
rng=np.random.default_rng(0); x=rng.normal(size=100); y=2*x+1+rng.normal(scale=.2,size=100)
idx=np.arange(100); rng.shuffle(idx); train, test=idx[:80],idx[80:]
print('train:',len(train),'test:',len(test))
