# %% [markdown]
# # Blog 36 — How Do We Measure What a Neural Network Has Learned?

# %%
import torch
z=torch.nn.functional.normalize(torch.randn(20,8),dim=1)
similarity=z@z.T
print('embedding shape:',z.shape); print('mean off-diagonal similarity:',(similarity.sum()-20)/380)
