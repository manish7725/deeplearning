# %% [markdown]
# # Blog 15 — How Can a Computer Represent the Meaning of a Word?

# %%
import torch
emb=torch.nn.Embedding(10,4)
ids=torch.tensor([1,3,7])
print(emb(ids)); print('shape:',emb(ids).shape)
