# %% [markdown]
# # Blog 25 — Why Does a Neural Network Generalize?

# %%
import numpy as np
train=np.array([1.,2.,3.]); test=np.array([4.,5.])
print('training points:',train); print('unseen points:',test)
