# %% [markdown]
# # Blog 19 — Can a Machine Create Something New?

# %%
import torch
z=torch.randn(4); print('latent sample:',z)
decoder=torch.nn.Linear(4,8); sample=decoder(z)
print('generated vector:',sample)
