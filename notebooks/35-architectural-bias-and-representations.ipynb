# %% [markdown]
# # Blog 35 — Why Does the Shape of a Neural Network Matter?

# %%
import torch
cnn=torch.nn.Conv2d(3,8,3,padding=1); x=torch.randn(1,3,32,32)
print('CNN output:',cnn(x).shape)
print('parameters:',sum(p.numel() for p in cnn.parameters()))
