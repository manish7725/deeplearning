# %% [markdown]
# # Blog 23 — Geometry, Invariance and Equivariance

# %%
import numpy as np
x=np.array([1.,2.]); R=np.array([[0.,-1.],[1.,0.]])
print('rotated:',R@x)
print('length preserved:',np.linalg.norm(x),np.linalg.norm(R@x))
