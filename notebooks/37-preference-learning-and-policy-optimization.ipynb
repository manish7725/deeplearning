# %% [markdown]
# # Blog 37 — How Can We Teach a Model What Humans Prefer?

# %%
import torch
scores=torch.tensor([1.2,.4]); preferences=torch.tensor([0])
loss=torch.nn.functional.cross_entropy(scores.unsqueeze(0),preferences)
print('preference loss:',loss.item())
