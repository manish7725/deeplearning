# %% [markdown]
# # Blog 30 — Out-of-Distribution and Robustness

# %%
import numpy as np
train=np.random.default_rng(0).normal(0,1,1000); ood=np.random.default_rng(1).normal(4,1,1000)
print('train mean:',train.mean(),'OOD mean:',ood.mean())
