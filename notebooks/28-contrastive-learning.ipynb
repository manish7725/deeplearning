# %% [markdown]
# # Blog 28 — Contrastive Learning

# %%
import torch
z=torch.nn.functional.normalize(torch.tensor([[1.,0.],[.9,.1],[0.,1.],[-1.,0.]]),dim=1)
sim=z@z.T; print('similarity matrix:
',sim)
